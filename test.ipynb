# %%
import dhlab.module_update as mu
mu.update('dhlab_v2')
import dhlab_v2 as d2
import imp
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\N_gram_dynamisk\dhlab_v2.py`

# %%
imp.reload(d2)
# Out:
# <module 'dhlab_v2' from 'C:\\Users\\larsj\\Documents\\GitHub\\N_gram_dynamisk\\dhlab_v2.py'>

# %%
a = d2.Ngram(['rosa', 'hvit', 'rød', 'blå','fiolett'], from_year = 1950, doctype = 'digibok')

# %%
a.plot()

# %%
ab = d2.Ngram_book(['rosa', 'hvit', 'rød', 'blå','fiolett'], from_year = 1950, to_year = 2010)

# %%
adj = d2.Ngram_book("god dårlig stor liten pen stygg".split(), from_year = 1950, to_year = 2010, ddk = "839%")

# %%
pb = d2.Ngram_book(". , i og på det".split(),from_year = 1950, to_year = 2010, ddk = "839%")

# %%
adj.compare(pb).plot(lw = 2.5, alpha = .7, figsize = (10,5))

# %%
p = d2.Ngram_book(['.',',','og','det','i'], from_year = 1800)

# %%
p.compare(p).plot()

# %%
ab.compare(p).plot(lw = 5, alpha =.6)

# %%
ab.compare(ab).plot()
